# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: folium in /shared-libs/python3.10/py/lib/python3.10/site-packages (from -r ./requirements.txt (line 1)) (0.13.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.10/py/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: mapclassify in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: mplleaflet==0.0.5 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 4)) (0.0.5)
# Requirement already satisfied: bokeh==3.1.0 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: pip in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 6)) (22.3.1)
# Requirement already satisfied: mgwr==2.1.2 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: statsmodels==0.13.5 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 8)) (0.13.5)
# Requirement already satisfied: xlrd in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: openpyxl in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 10)) (3.1.2)
# Requirement already satisfied: pysal in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 11)) (23.1)
# Requirement already satisfied: jinja2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from mplleaflet==0.0.5->-r ./requirements.txt (line 4)) (2.11.3)
# Requirement already satisfied: six in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from mplleaflet==0.0.5->-r ./requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: contourpy>=1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: packaging>=16.8 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: pillow>=7.1.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (9.2.0)
# Requirement already satisfied: PyYAML>=3.10 in /root/venv/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (6.0)
# Requirement already satisfied: pandas>=1.2 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (1.2.5)
# Requirement already satisfied: xyzservices>=2021.09.1 in /root/venv/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (2023.2.0)
# Requirement already satisfied: numpy>=1.16 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (1.23.4)
# Requirement already satisfied: tornado>=5.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from bokeh==3.1.0->-r ./requirements.txt (line 5)) (6.2)
# Requirement already satisfied: spreg in /root/venv/lib/python3.10/site-packages (from mgwr==2.1.2->-r ./requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: spglm>=1.0.6 in /root/venv/lib/python3.10/site-packages (from mgwr==2.1.2->-r ./requirements.txt (line 7)) (1.0.8)
# Requirement already satisfied: libpysal>=4.0.0 in /root/venv/lib/python3.10/site-packages (from mgwr==2.1.2->-r ./requirements.txt (line 7)) (4.7.0)
# Requirement already satisfied: scipy>=0.11 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from mgwr==2.1.2->-r ./requirements.txt (line 7)) (1.9.3)
# Requirement already satisfied: patsy>=0.5.2 in /root/venv/lib/python3.10/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: branca>=0.3.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from folium->-r ./requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: requests in /shared-libs/python3.10/py/lib/python3.10/site-packages (from folium->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.10/py/lib/python3.10/site-packages (from mapclassify->-r ./requirements.txt (line 3)) (1.1.2)
# Requirement already satisfied: networkx in /root/venv/lib/python3.10/site-packages (from mapclassify->-r ./requirements.txt (line 3)) (3.1)
# Requirement already satisfied: et-xmlfile in /root/venv/lib/python3.10/site-packages (from openpyxl->-r ./requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: esda>=2.4.1 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (2.4.3)
# Requirement already satisfied: momepy>=0.5.4 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (0.5.4)
# Requirement already satisfied: access>=1.1.8 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (1.1.8)
# Requirement already satisfied: segregation>=2.3.1 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (2.3.1)
# Requirement already satisfied: spaghetti>=1.7.2 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (1.7.2)
# Requirement already satisfied: spint>=1.0.7 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (1.0.7)
# Requirement already satisfied: spvcm>=0.3.0 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: pointpats>=2.2.0 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: spopt>=0.5.0 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: inequality>=1.0.0 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: tobler>=0.8.2 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: giddy>=2.3.3 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (2.3.4)
# Requirement already satisfied: splot>=1.1.5.post1 in /root/venv/lib/python3.10/site-packages (from pysal->-r ./requirements.txt (line 11)) (1.1.5.post1)
# Requirement already satisfied: geopandas in /shared-libs/python3.10/py/lib/python3.10/site-packages (from access>=1.1.8->pysal->-r ./requirements.txt (line 11)) (0.11.1)
# Requirement already satisfied: quantecon>=0.4.7 in /root/venv/lib/python3.10/site-packages (from giddy>=2.3.3->pysal->-r ./requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jinja2->mplleaflet==0.0.5->-r ./requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.1.2->-r ./requirements.txt (line 7)) (4.11.1)
# Requirement already satisfied: platformdirs in /root/venv/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.1.2->-r ./requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from momepy>=0.5.4->pysal->-r ./requirements.txt (line 11)) (4.64.1)
# Requirement already satisfied: pygeos in /root/venv/lib/python3.10/site-packages (from momepy>=0.5.4->pysal->-r ./requirements.txt (line 11)) (0.14)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pandas>=1.2->bokeh==3.1.0->-r ./requirements.txt (line 5)) (2022.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests->folium->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests->folium->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests->folium->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests->folium->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: seaborn in /shared-libs/python3.10/py/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: numba in /root/venv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.56.4)
# Requirement already satisfied: rvlib>=0.0.5 in /root/venv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.0.6)
# Requirement already satisfied: deprecation in /root/venv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: pyproj>=3 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: quilt3 in /root/venv/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: joblib in /shared-libs/python3.10/py/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from scikit-learn->mapclassify->-r ./requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: rtree in /root/venv/lib/python3.10/site-packages (from spaghetti>=1.7.2->pysal->-r ./requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: pulp in /root/venv/lib/python3.10/site-packages (from spopt>=0.5.0->pysal->-r ./requirements.txt (line 11)) (2.7.0)
# Requirement already satisfied: rasterstats in /root/venv/lib/python3.10/site-packages (from tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (0.18.0)
# Requirement already satisfied: rasterio in /root/venv/lib/python3.10/site-packages (from tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (1.3.6)
# Requirement already satisfied: fiona>=1.8 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from geopandas->access>=1.1.8->pysal->-r ./requirements.txt (line 11)) (1.8.22)
# Requirement already satisfied: shapely<2,>=1.7 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from geopandas->access>=1.1.8->pysal->-r ./requirements.txt (line 11)) (1.8.5.post1)
# Requirement already satisfied: sympy in /shared-libs/python3.10/py/lib/python3.10/site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal->-r ./requirements.txt (line 11)) (1.11.1)
# Requirement already satisfied: cffi>=1.0.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from rvlib>=0.0.5->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.15.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.10/site-packages (from numba->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (65.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /root/venv/lib/python3.10/site-packages (from numba->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.39.1)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from beautifulsoup4->libpysal>=4.0.0->mgwr==2.1.2->-r ./requirements.txt (line 7)) (2.3.2.post1)
# Requirement already satisfied: requests-futures==1.0.0 in /root/venv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: boto3>=1.10.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.24.95)
# Requirement already satisfied: jsonschema<5,>=3 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (3.2.0)
# Requirement already satisfied: jsonlines==1.2.0 in /root/venv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: aws-requests-auth>=0.4.2 in /root/venv/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.4.3)
# Requirement already satisfied: tenacity>=5.1.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (8.1.0)
# Requirement already satisfied: cligj>=0.5 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: click>=4.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (8.1.3)
# Requirement already satisfied: snuggs>=1.4.1 in /root/venv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (1.4.7)
# Requirement already satisfied: affine in /root/venv/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (2.4.0)
# Requirement already satisfied: click-plugins in /shared-libs/python3.10/py/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: attrs in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (22.1.0)
# Requirement already satisfied: simplejson in /root/venv/lib/python3.10/site-packages (from rasterstats->tobler>=0.8.2->pysal->-r ./requirements.txt (line 11)) (3.19.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from boto3>=1.10.0->quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from boto3>=1.10.0->quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.95 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from boto3>=1.10.0->quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (1.27.95)
# Requirement already satisfied: pycparser in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from cffi>=1.0.0->rvlib>=0.0.5->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (2.21)
# Requirement already satisfied: munch in /shared-libs/python3.10/py/lib/python3.10/site-packages (from fiona>=1.8->geopandas->access>=1.1.8->pysal->-r ./requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema<5,>=3->quilt3->segregation>=2.3.1->pysal->-r ./requirements.txt (line 11)) (0.18.1)
# Requirement already satisfied: mpmath>=0.19 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal->-r ./requirements.txt (line 11)) (1.2.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cfc4dc78-fd2a-4b67-8dea-b0c970af57ec' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
